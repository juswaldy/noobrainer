# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# dataset with tokenized titles
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FourthBrain ML Engineer/4B_GLG/Datasets/y_X_train_tokenized_4e_backup_to70k.csv', encoding="latin1")
df
# Out:
#         Unnamed: 0  article_number  \
# 0                0           34557
# 1                1          104289
# 2                2           61632
# 3                3           78993
# 4                4           74769
# ...            ...             ...
# 150295       70095          119539
# 150296       70096          110874
# 150297       70097           76610
# 150298       70098           23255
# 150299       70099          125609
#
#                                               title_clean  \
# 0       target revamps chemical use policy asks suppli...
# 1                   poland cyfrowy polsat begins roll out
# 2                                brief sc provides update
# 3       uber arizona governor suspends ability to test...
# 4       atrium health says data of about million patie...
# ...                                                   ...
# 150295  cdc issues virus travel alert on most of europ...
# 150296                  brief adcock ingram hy heps cents
# ...

# %%
# additional manual processing after file reload, if needed

df.drop(df.columns[0:1], axis=1, inplace=True)
df.columns.values[0] = "article_number"

df.head()
# Out:
#    article_number                                        title_clean  \
# 0           34557  target revamps chemical use policy asks suppli...
# 1          104289              poland cyfrowy polsat begins roll out
# 2           61632                           brief sc provides update
# 3           78993  uber arizona governor suspends ability to test...
# 4           74769  atrium health says data of about million patie...
#
#                                        article_clean  \
# 0  reuters target corp said it would introduce po...
# 1  warsaw reuters poland cyfrowy polsat said on f...
# 2  april reuters sc ag dgap news sc provides upda...
# 3  the governor of arizona on monday suspended ub...
# 4  reuters atrium health previously carolinas hea...
#
#                                      title_tokenized  \
# 0  [target, chemical, use, policy, suppliers, ing...
# 1                    [poland, cyfrowy, polsat, roll]
# 2                                [brief, sc, update]
# ...

# %%
path = '/content/drive/MyDrive/Colab Notebooks/FourthBrain ML Engineer/4B_GLG/Datasets/a_X_train_tokenized_4.01.csv'

# %%
with open(path, 'w', encoding = 'latin1') as f:
  df[0:0].to_csv(f)

# %%
df
# Out:
#         article_number                                        title_clean  \
# 0                34557  target revamps chemical use policy asks suppli...
# 1               104289              poland cyfrowy polsat begins roll out
# 2                61632                           brief sc provides update
# 3                78993  uber arizona governor suspends ability to test...
# 4                74769  atrium health says data of about million patie...
# ...                ...                                                ...
# 150295          119539  cdc issues virus travel alert on most of europ...
# 150296          110874                  brief adcock ingram hy heps cents
# 150297           76610  facebook russia sponsored accounts to be inclu...
# 150298           23255  kids still getting hurt riding atvs despite sa...
# 150299          125609    brief coface says moody confirms its ifs rating
#
#                                             article_clean  \
# ...

# %%
check_df = pd.read_csv(path, encoding='latin1')
# check_df = pd.read_csv(path, encoding='utf-8-sig')
check_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, article_number, title_clean, article_clean, title_tokenized, article_tokenized]
# Index: []

# %%
# import re

# path_save = '/content/drive/MyDrive/Colab Notebooks/FourthBrain ML Engineer/4B_GLG/Datasets/X_train_tokenized_article_regex.csv'

# start = 0
# end = df.shape[0]

# for i in range(start,end):
#   df.article_clean.iloc[i] = [re.sub('[\u0080-\uFFFF]+', '_', x) for x in df.article_clean.iloc[i]]
#   df.article_clean.iloc[i] = ''.join(df.article_clean.iloc[i])

# # save file
# # with open(path_save, 'w', encoding = 'utf-8-sig') as f:
# with open(path_save, 'w', encoding = 'latin1') as f:
#   df.to_csv(f)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# path = '/content/drive/MyDrive/Colab Notebooks/FourthBrain ML Engineer/4B_GLG/Datasets/X_train_tokenized_article_regex.csv'

# with open(path, 'w', encoding = 'utf-8-sig') as f:
#   df.to_csv(f)
